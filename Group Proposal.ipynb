# %%
library(repr)
library(readr)
library(tidyverse)
library(tidymodels)
library(RColorBrewer)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ dplyr   1.0.9
# ✔ tibble  3.1.7     ✔ stringr 1.4.0
# ✔ tidyr   1.2.0     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Learn how to get started at https://www.tidymodels.org/start/

# %% [markdown]
# 1. Demonstrate that the dataset can be read from the web into R.

# %%
web_data <- "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
redwine_data <- read_delim(web_data,col_names=FALSE) |>
    rename(fixed_acidity = X1, 
          volatile_acidity = X2,
          citric_acid = X3,
          residual_sugar = X4,
          chlorides = X5,
          free_sulfur_dioxide = X6,
          total_sulfur_dioxide = X7,
          density = X8,
          pH = X9,
          sulphates = X10,
          alcohol = X11,
          quality = X12) |>
    mutate(quality = as_factor(quality))
redwine_data
# Out:
# Rows: 1600 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# chr (12): X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      fixed_acidity volatile_acidity citric_acid residual_sugar chlorides
# 1    fixed acidity volatile acidity citric acid residual sugar chlorides
# 2    7.4           0.7              0           1.9            0.076
# 3    7.8           0.88             0           2.6            0.098
# 4    7.8           0.76             0.04        2.3            0.092
# 5    11.2          0.28             0.56        1.9            0.075
# 6    7.4           0.7              0           1.9            0.076
# 7    7.4           0.66             0           1.8            0.075
# 8    7.9           0.6              0.06        1.6            0.069
# 9    7.3           0.65             0           1.2            0.065
# 10   7.8           0.58             0.02        2              0.073
# 11   7.5           0.5              0.36        6.1            0.071
# 12   6.7           0.58             0.08        1.8            0.097
# 13   7.5           0.5              0.36        6.1            0.071
# 14   5.6           0.615            0           1.6            0.089
# 15   7.8           0.61             0.29        1.6            0.114
# 16   8.9           0.62             0.18        3.8            0.176
# 17   8.9           0.62             0.19        3.9            0.17
# 18   8.5           0.28             0.56        1.8            0.092
# 19   8.1           0.56             0.28        1.7            0.368
# 20   7.4           0.59             0.08        4.4            0.086
# 21   7.9           0.32             0.51        1.8            0.341
# 22   8.9           0.22             0.48        1.8            0.077
# 23   7.6           0.39             0.31        2.3            0.082
# 24   7.9           0.43             0.21        1.6            0.106
# 25   8.5           0.49             0.11        2.3            0.084
# 26   6.9           0.4              0.14        2.4            0.085
# 27   6.3           0.39             0.16        1.4            0.08
# 28   7.6           0.41             0.24        1.8            0.08
# 29   7.9           0.43             0.21        1.6            0.106
# 30   7.1           0.71             0           1.9            0.08
# ⋮    ⋮             ⋮                ⋮           ⋮              ⋮
# 1571 6.2           0.51             0.14        1.9            0.056
# 1572 6.4           0.36             0.53        2.2            0.23
# 1573 6.4           0.38             0.14        2.2            0.038
# 1574 7.3           0.69             0.32        2.2            0.069
# 1575 6             0.58             0.2         2.4            0.075
# 1576 5.6           0.31             0.78        13.9           0.074
# 1577 7.5           0.52             0.4         2.2            0.06
# 1578 8             0.3              0.63        1.6            0.081
# 1579 6.2           0.7              0.15        5.1            0.076
# 1580 6.8           0.67             0.15        1.8            0.118
# 1581 6.2           0.56             0.09        1.7            0.053
# 1582 7.4           0.35             0.33        2.4            0.068
# 1583 6.2           0.56             0.09        1.7            0.053
# 1584 6.1           0.715            0.1         2.6            0.053
# 1585 6.2           0.46             0.29        2.1            0.074
# 1586 6.7           0.32             0.44        2.4            0.061
# 1587 7.2           0.39             0.44        2.6            0.066
# 1588 7.5           0.31             0.41        2.4            0.065
# 1589 5.8           0.61             0.11        1.8            0.066
# 1590 7.2           0.66             0.33        2.5            0.068
# 1591 6.6           0.725            0.2         7.8            0.073
# 1592 6.3           0.55             0.15        1.8            0.077
# 1593 5.4           0.74             0.09        1.7            0.089
# 1594 6.3           0.51             0.13        2.3            0.076
# 1595 6.8           0.62             0.08        1.9            0.068
# 1596 6.2           0.6              0.08        2              0.09
# 1597 5.9           0.55             0.1         2.2            0.062
# 1598 6.3           0.51             0.13        2.3            0.076
# 1599 5.9           0.645            0.12        2              0.075
# 1600 6             0.31             0.47        3.6            0.067
#      free_sulfur_dioxide total_sulfur_dioxide density pH   sulphates alcohol
# 1    free sulfur dioxide total sulfur dioxide density pH   sulphates alcohol
# 2    11                  34                   0.9978  3.51 0.56      9.4
# 3    25                  67                   0.9968  3.2  0.68      9.8
# 4    15                  54                   0.997   3.26 0.65      9.8
# 5    17                  60                   0.998   3.16 0.58      9.8
# 6    11                  34                   0.9978  3.51 0.56      9.4
# 7    13                  40                   0.9978  3.51 0.56      9.4
# 8    15                  59                   0.9964  3.3  0.46      9.4
# 9    15                  21                   0.9946  3.39 0.47      10
# 10   9                   18                   0.9968  3.36 0.57      9.5
# 11   17                  102                  0.9978  3.35 0.8       10.5
# 12   15                  65                   0.9959  3.28 0.54      9.2
# 13   17                  102                  0.9978  3.35 0.8       10.5
# 14   16                  59                   0.9943  3.58 0.52      9.9
# 15   9                   29                   0.9974  3.26 1.56      9.1
# 16   52                  145                  0.9986  3.16 0.88      9.2
# 17   51                  148                  0.9986  3.17 0.93      9.2
# 18   35                  103                  0.9969  3.3  0.75      10.5
# 19   16                  56                   0.9968  3.11 1.28      9.3
# 20   6                   29                   0.9974  3.38 0.5       9
# 21   17                  56                   0.9969  3.04 1.08      9.2
# 22   29                  60                   0.9968  3.39 0.53      9.4
# 23   23                  71                   0.9982  3.52 0.65      9.7
# 24   10                  37                   0.9966  3.17 0.91      9.5
# 25   9                   67                   0.9968  3.17 0.53      9.4
# 26   21                  40                   0.9968  3.43 0.63      9.7
# 27   11                  23                   0.9955  3.34 0.56      9.3
# 28   4                   11                   0.9962  3.28 0.59      9.5
# 29   10                  37                   0.9966  3.17 0.91      9.5
# 30   14                  35                   0.9972  3.47 0.55      9.4
# ⋮    ⋮                   ⋮                    ⋮       ⋮    ⋮         ⋮
# 1571 15                  34                   0.99396 3.48 0.57      11.5
# 1572 19                  35                   0.9934  3.37 0.93      12.4
# 1573 15                  25                   0.99514 3.44 0.65      11.1
# 1574 35                  104                  0.99632 3.33 0.51      9.5
# 1575 15                  50                   0.99467 3.58 0.67      12.5
# 1576 23                  92                   0.99677 3.39 0.48      10.5
# 1577 12                  20                   0.99474 3.26 0.64      11.8
# 1578 16                  29                   0.99588 3.3  0.78      10.8
# 1579 13                  27                   0.99622 3.54 0.6       11.9
# 1580 13                  20                   0.9954  3.42 0.67      11.3
# 1581 24                  32                   0.99402 3.54 0.6       11.3
# 1582 9                   26                   0.9947  3.36 0.6       11.9
# 1583 24                  32                   0.99402 3.54 0.6       11.3
# 1584 13                  27                   0.99362 3.57 0.5       11.9
# 1585 32                  98                   0.99578 3.33 0.62      9.8
# 1586 24                  34                   0.99484 3.29 0.8       11.6
# 1587 22                  48                   0.99494 3.3  0.84      11.5
# 1588 34                  60                   0.99492 3.34 0.85      11.4
# 1589 18                  28                   0.99483 3.55 0.66      10.9
# 1590 34                  102                  0.99414 3.27 0.78      12.8
# 1591 29                  79                   0.9977  3.29 0.54      9.2
# 1592 26                  35                   0.99314 3.32 0.82      11.6
# 1593 16                  26                   0.99402 3.67 0.56      11.6
# 1594 29                  40                   0.99574 3.42 0.75      11
# 1595 28                  38                   0.99651 3.42 0.82      9.5
# 1596 32                  44                   0.9949  3.45 0.58      10.5
# 1597 39                  51                   0.99512 3.52 0.76      11.2
# 1598 29                  40                   0.99574 3.42 0.75      11
# 1599 32                  44                   0.99547 3.57 0.71      10.2
# 1600 18                  42                   0.99549 3.39 0.66      11
#      quality
# 1    quality
# 2    5
# 3    5
# 4    5
# 5    6
# 6    5
# 7    5
# 8    5
# 9    7
# 10   7
# 11   5
# 12   5
# 13   5
# 14   5
# 15   5
# 16   5
# 17   5
# 18   7
# 19   5
# 20   4
# 21   6
# 22   6
# 23   5
# 24   5
# 25   5
# 26   6
# 27   5
# 28   5
# 29   5
# 30   5
# ⋮    ⋮
# 1571 6
# 1572 6
# 1573 6
# 1574 5
# 1575 6
# 1576 6
# 1577 6
# 1578 6
# 1579 6
# 1580 6
# 1581 5
# 1582 6
# 1583 5
# 1584 5
# 1585 5
# 1586 7
# 1587 6
# 1588 6
# 1589 6
# 1590 6
# 1591 5
# 1592 6
# 1593 6
# 1594 6
# 1595 6
# 1596 5
# 1597 6
# 1598 6
# 1599 5
# 1600 6

# %% [markdown]
# 2. Clean and wrangle your data into a tidy format.

# %% [markdown]
# 3. Using only training data, summarize the data in at least one table (this is exploratory data analysis). An example of a useful table could be one that reports the number of observations in each class, the means of the predictor variables you plan to use in your analysis and how many rows have missing data.

# %% [markdown]
# 4. Using only training data, visualize the data with at least one plot relevant to the analysis you plan to do (this is exploratory data analysis). An example of a useful visualization could be one that compares the distributions of each of the predictor variables you plan to use in your analysis.
